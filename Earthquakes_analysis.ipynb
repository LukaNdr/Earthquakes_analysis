# %%
import numpy as np
import pandas as pd
df = pd.read_csv('Earthquakes_database.csv')
df.head()
# Out:
#        Date      Time  Latitude  Longitude        Type  Depth  Depth Error  \
# 0  1/2/1965  13:44:18    19.246    145.616  Earthquake  131.6          NaN
# 1  1/4/1965  11:29:49     1.863    127.352  Earthquake   80.0          NaN
# 2  1/5/1965  18:05:58   -20.579   -173.972  Earthquake   20.0          NaN
# 3  1/8/1965  18:49:43   -59.076    -23.557  Earthquake   15.0          NaN
# 4  1/9/1965  13:32:50    11.938    126.427  Earthquake   15.0          NaN
#
#    Depth Seismic Stations  Magnitude Magnitude Type  ...  \
# 0                     NaN        6.0             MW  ...
# 1                     NaN        5.8             MW  ...
# 2                     NaN        6.2             MW  ...
# 3                     NaN        5.8             MW  ...
# 4                     NaN        5.8             MW  ...
#
#    Magnitude Seismic Stations  Azimuthal Gap  Horizontal Distance  \
# 0                         NaN            NaN                  NaN
# ...

# %%
df = df.drop_duplicates()
df
# Out:
#              Date      Time  Latitude  Longitude        Type   Depth  \
# 0        1/2/1965  13:44:18   19.2460   145.6160  Earthquake  131.60
# 1        1/4/1965  11:29:49    1.8630   127.3520  Earthquake   80.00
# 2        1/5/1965  18:05:58  -20.5790  -173.9720  Earthquake   20.00
# 3        1/8/1965  18:49:43  -59.0760   -23.5570  Earthquake   15.00
# 4        1/9/1965  13:32:50   11.9380   126.4270  Earthquake   15.00
# ...           ...       ...       ...        ...         ...     ...
# 23407  12/28/2016   8:22:12   38.3917  -118.8941  Earthquake   12.30
# 23408  12/28/2016   9:13:47   38.3777  -118.8957  Earthquake    8.80
# 23409  12/28/2016  12:38:51   36.9179   140.4262  Earthquake   10.00
# 23410  12/29/2016  22:30:19   -9.0283   118.6639  Earthquake   79.00
# 23411  12/30/2016  20:08:28   37.3973   141.4103  Earthquake   11.94
#
#        Depth Error  Depth Seismic Stations  Magnitude Magnitude Type  ...  \
# ...

# %%
df = df.drop(columns = "ID")
df
# Out:
#              Date      Time  Latitude  Longitude        Type   Depth  \
# 0        1/2/1965  13:44:18   19.2460   145.6160  Earthquake  131.60
# 1        1/4/1965  11:29:49    1.8630   127.3520  Earthquake   80.00
# 2        1/5/1965  18:05:58  -20.5790  -173.9720  Earthquake   20.00
# 3        1/8/1965  18:49:43  -59.0760   -23.5570  Earthquake   15.00
# 4        1/9/1965  13:32:50   11.9380   126.4270  Earthquake   15.00
# ...           ...       ...       ...        ...         ...     ...
# 23407  12/28/2016   8:22:12   38.3917  -118.8941  Earthquake   12.30
# 23408  12/28/2016   9:13:47   38.3777  -118.8957  Earthquake    8.80
# 23409  12/28/2016  12:38:51   36.9179   140.4262  Earthquake   10.00
# 23410  12/29/2016  22:30:19   -9.0283   118.6639  Earthquake   79.00
# 23411  12/30/2016  20:08:28   37.3973   141.4103  Earthquake   11.94
#
#        Depth Error  Depth Seismic Stations  Magnitude Magnitude Type  \
# ...

# %%
df[["Month", "day", "Year"]] = df["Date"].str.split('/',2, expand=True)
df
# Out:
# <ipython-input-6-2c4456730af5>:1: FutureWarning: In a future version of pandas all arguments of StringMethods.split except for the argument 'pat' will be keyword-only.
#   df[["Month", "day", "Year"]] = df["Date"].str.split('/',2, expand=True)
#              Date      Time  Latitude  Longitude        Type   Depth  \
# 0        1/2/1965  13:44:18   19.2460   145.6160  Earthquake  131.60
# 1        1/4/1965  11:29:49    1.8630   127.3520  Earthquake   80.00
# 2        1/5/1965  18:05:58  -20.5790  -173.9720  Earthquake   20.00
# 3        1/8/1965  18:49:43  -59.0760   -23.5570  Earthquake   15.00
# 4        1/9/1965  13:32:50   11.9380   126.4270  Earthquake   15.00
# ...           ...       ...       ...        ...         ...     ...
# 23407  12/28/2016   8:22:12   38.3917  -118.8941  Earthquake   12.30
# 23408  12/28/2016   9:13:47   38.3777  -118.8957  Earthquake    8.80
# 23409  12/28/2016  12:38:51   36.9179   140.4262  Earthquake   10.00
# ...

# %%
bins = [0, 50, 150, float('inf')]
labels = ['Normal', 'Depth', 'Very depth']

df['Depth_Category'] = pd.cut(df['Depth'], bins=bins, labels=labels, right=False)

df.head()
# Out:
#        Date      Time  Latitude  Longitude        Type  Depth  Depth Error  \
# 0  1/2/1965  13:44:18    19.246    145.616  Earthquake  131.6          NaN
# 1  1/4/1965  11:29:49     1.863    127.352  Earthquake   80.0          NaN
# 2  1/5/1965  18:05:58   -20.579   -173.972  Earthquake   20.0          NaN
# 3  1/8/1965  18:49:43   -59.076    -23.557  Earthquake   15.0          NaN
# 4  1/9/1965  13:32:50    11.938    126.427  Earthquake   15.0          NaN
#
#    Depth Seismic Stations  Magnitude Magnitude Type  ...  Horizontal Error  \
# 0                     NaN        6.0             MW  ...               NaN
# 1                     NaN        5.8             MW  ...               NaN
# 2                     NaN        6.2             MW  ...               NaN
# 3                     NaN        5.8             MW  ...               NaN
# 4                     NaN        5.8             MW  ...               NaN
#
# ...

# %%
df_stacked=df.stack()
df_stacked
# Out:
# 0      Date                1/2/1965
#        Time                13:44:18
#        Latitude              19.246
#        Longitude            145.616
#        Type              Earthquake
#                             ...
# 23411  Status              Reviewed
#        Month                     12
#        day                       30
#        Year                    2016
#        Depth_Category        Normal
# Length: 416440, dtype: object

# %%
df.melt()
# Out:
#               variable     value
# 0                 Date  1/2/1965
# 1                 Date  1/4/1965
# 2                 Date  1/5/1965
# 3                 Date  1/8/1965
# 4                 Date  1/9/1965
# ...                ...       ...
# 561883  Depth_Category    Normal
# 561884  Depth_Category    Normal
# 561885  Depth_Category    Normal
# 561886  Depth_Category     Depth
# 561887  Depth_Category    Normal
#
# [561888 rows x 2 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.figure(figsize=(10, 6))
df.groupby('Year')['Magnitude'].count().plot(kind='line', marker='o', color='blue')
plt.title('Earthquake Count Over the Years')
plt.xlabel('Year')
plt.ylabel('Number of Earthquakes')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(8, 5))
sns.countplot(x='Depth_Category', data=df, palette='viridis')
plt.title('Distribution of Earthquakes by Depth Category')
plt.xlabel('Depth Category')
plt.ylabel('Count')
plt.show()

# %%
plt.figure(figsize=(12, 8))
plt.scatter(df['Longitude'], df['Latitude'], c='red', alpha=0.5, edgecolors='k', linewidths=0.5)
plt.title('Earthquake Distribution - Latitude vs Longitude')
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.grid(True)
plt.show()

# %%
depth_category_counts = df['Depth_Category'].value_counts()
plt.figure(figsize=(8, 8))
plt.pie(depth_category_counts, labels=depth_category_counts.index, autopct='%1.1f%%', startangle=140, colors=['skyblue', 'lightgreen', 'lightcoral'])
plt.title('Proportion of Earthquakes by Depth Category')
plt.show()

# %%
df['Date'] = pd.to_datetime(df['Date'], utc=True)

print(df['Date'].dtype)

if df['Date'].dtype == 'datetime64[ns, UTC]':
    df['DayOfWeek'] = df['Date'].dt.day_name()

print(df[['Date', 'DayOfWeek']].head())
# Out:
# datetime64[ns, UTC]
#                        Date DayOfWeek
# 0 1965-01-02 00:00:00+00:00  Saturday
# 1 1965-01-04 00:00:00+00:00    Monday
# 2 1965-01-05 00:00:00+00:00   Tuesday
# 3 1965-01-08 00:00:00+00:00    Friday
# 4 1965-01-09 00:00:00+00:00  Saturday

# %%
df['Date'] = pd.to_datetime(df['Date'])
df['DayOfWeek'] = df['Date'].dt.day_name()

# Display the DataFrame with the new column
print(df[['Date', 'DayOfWeek']].head())
# Out:
#                        Date DayOfWeek
# 0 1965-01-02 00:00:00+00:00  Saturday
# 1 1965-01-04 00:00:00+00:00    Monday
# 2 1965-01-05 00:00:00+00:00   Tuesday
# 3 1965-01-08 00:00:00+00:00    Friday
# 4 1965-01-09 00:00:00+00:00  Saturday

# %%
df.set_index('Date', inplace=True)

# Resample to monthly frequency and calculate the mean magnitude
monthly_avg_magnitude = df['Magnitude'].resample('M').mean()

# Display the resampled data
print(monthly_avg_magnitude.head())
# Out:
# Date
# 1965-01-31 00:00:00+00:00    6.123077
# 1965-02-28 00:00:00+00:00    5.955556
# 1965-03-31 00:00:00+00:00    6.057895
# 1965-04-30 00:00:00+00:00    5.945455
# 1965-05-31 00:00:00+00:00    5.954545
# Freq: M, Name: Magnitude, dtype: float64
